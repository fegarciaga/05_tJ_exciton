# %% [markdown]
# # Bethe-Salpeter estática para un ángulo fijo
#
# Este notebook calcula el propagador excitónico retarded
#
# $$D^R_{\mu\nu}(\Omega;\theta)=\left[V^{-1}\delta_{\mu\nu}-\Pi^R_{\mu\nu}(\Omega;\theta)\right]^{-1},$$
#
# para dos capas electrónicas acopladas a magnetizaciones clásicas $\mathbf M_1$ y $\mathbf M_2$ con ángulo relativo fijo $\theta$.
#
# El punto importante es que seguimos la estructura del documento: partimos de la burbuja en el contorno, tomamos su componente retardada con reglas de Langreth, y recién después pasamos a frecuencia.

# %% [markdown]
# ## Espacios: capa, spin y vértice excitónico
#
# La base microscópica completa es
#
# $$\Psi=(c^1_\uparrow,c^1_\downarrow,c^2_\uparrow,c^2_\downarrow)^T,$$
#
# que vive en
#
# $$\mathcal H_{\rm layer}\otimes\mathcal H_{\rm spin}.$$
#
# Las matrices de Pauli $\sigma^a_{\rm spin}$ del acoplamiento $s$-$d$ actúan en el **spin físico dentro de cada capa**:
#
# $$h_l(k)=\epsilon_l(k)\sigma^0_{\rm spin}-J_{sd}\,\mathbf M_l\cdot\boldsymbol\sigma_{\rm spin}.$$
#
# En cambio, el campo excitónico
#
# $$B^{\sigma\sigma'}=c^{1\dagger}_\sigma c^2_{\sigma'}$$
#
# conecta capa 2 con capa 1. Su descomposición
#
# $$B^\mu={\rm Tr}_{\rm spin}[\Gamma^\mu B],\qquad \Gamma^\mu=\sigma^\mu_{\rm spin}/\sqrt{2}$$
#
# usa $\Gamma^\mu$ como **vértice en el espacio de spin del par electrón-hueco**. La estructura de capa está en que el vértice conecta $2\to1$; en este notebook trabajamos por bloques, con $G_1$ y $G_2$ como Green functions de spin $2\times2$ de cada capa.
#
# La burbuja del documento se escribe entonces como traza solo sobre spin:
#
# $$\Pi_{\mu\nu}(z,z')=-\frac{i}{L}\sum_k {\rm Tr}_{\rm spin}\left[\Gamma_\mu^\dagger G^1_M(k;z,z')\Gamma_\nu G^2_M(k;z',z)\right].$$

# %% [markdown]
# ## Componente retardada
#
# Aplicando Langreth y usando invariancia temporal de traslación para una configuración magnética congelada,
#
# $$\Pi^R_{\mu\nu}(\Omega)=-\frac{i}{L}\sum_k\int\frac{d\omega}{2\pi}{\rm Tr}_{\rm spin}\left[\Gamma_\mu^\dagger G^{1,R}_M(k,\omega+\Omega)\Gamma_\nu G^{2,<}_M(k,\omega)+\Gamma_\mu^\dagger G^{1,<}_M(k,\omega+\Omega)\Gamma_\nu G^{2,A}_M(k,\omega)\right].$$
#
# Usamos
#
# $$G_l^R(k,\omega)=[\omega+i\eta_e-h_l(k)]^{-1},\qquad G_l^A=(G_l^R)^\dagger,$$
#
# $$G_l^<(k,\omega)=f(\omega)\left[G_l^A(k,\omega)-G_l^R(k,\omega)\right].$$
#
# La suma de bandas se deja como benchmark, no como cálculo principal.

# %%
using LinearAlgebra
using Printf
using PyPlot

rc("font", family="serif")
rc("font", size=13)
rc("axes", labelsize=14, titlesize=14)
rc("legend", fontsize=10)

# %%
# -----------------------------
# Parámetros físicos y numéricos
# Los defaults son de notebook/smoke test. Para producción subir L, NΩ y Nω.
# -----------------------------
L = 100#36                        # puntos de momento; subir para producción
γ = 1.0                       # hopping intralayer
Δ_layer = 8.0                 # offset energético entre capas: ε1=+Δ/2+εk, ε2=-Δ/2+εk
Jsd = 0.35                    # acoplamiento s-d
Mmag = 1.0                    # magnitud de las magnetizaciones clásicas
θ = 0.0#π/4                   # ángulo fijo entre M1 y M2
V = -1.2                      # atracción excitónica efectiva en D=(V^{-1}-Π)^{-1}
T = 0.08                      # temperatura electrónica
μchem = 0.0                   # potencial químico común
μbias = 0.5                   # desbalance químico entre capas: μ1-μ2
μ1 = μchem + μbias/2          # potencial químico de capa 1/conducción
μ2 = μchem - μbias/2          # potencial químico de capa 2/valencia
ηe = 0.08                     # ensanchamiento de los Green functions electrónicos
ηΩ = 2ηe                      # anchura efectiva del benchmark de bandas

Ωmin, Ωmax, NΩ = 0.0, 15.0, 401#121 -20.0
ωmin, ωmax, Nω = -15.0, 15.0, 601#601#401
ks = collect(range(-π, stop=π - 2π/L, length=L))
Ωs = collect(range(Ωmin, Ωmax, length=NΩ))
ωs = collect(range(ωmin, ωmax, length=Nω))
dω = ωs[2] - ωs[1];

# %%
# Pauli en el espacio de spin físico.
σ_spin_0 = ComplexF64[1 0; 0 1]
σ_spin_x = ComplexF64[0 1; 1 0]
σ_spin_y = ComplexF64[0 -im; im 0]
σ_spin_z = ComplexF64[1 0; 0 -1]
σ_spin = [σ_spin_0, σ_spin_x, σ_spin_y, σ_spin_z]

# Vértices excitónicos. Son matrices 2x2 entre las copias de spin de capa 2 y capa 1.
# La estructura inter-capa no está en Γ; está en el bilineal c1† Γ c2.
Γ_exciton = σ_spin ./ sqrt(2)
channel_labels = ["0", "x", "y", "z"];

# %%
ϵk(k; γ=γ) = -2γ*cos(k)

function fermi(E; T=T, μ=0.0)
    x = (E - μ) / T
    x > 60 && return 0.0
    x < -60 && return 1.0
    return 1 / (exp(x) + 1)
end

function layer_chemical_potential(layer::Int)
    return layer == 1 ? μ1 : μ2
end

function h_layer(k, M; layer::Int)
    offset = layer == 1 ? +Δ_layer/2 : Δ_layer/2
    energy = (ϵk(k) + offset) * σ_spin_0 - Jsd * (M[1]*σ_spin_x + M[2]*σ_spin_y + M[3]*σ_spin_z)
    energy .*= (-1)^(layer+1)
    energy .-= layer_chemical_potential(layer) * σ_spin_0
    return energy
end

function magnetizations(θ)
    M1 = Mmag .* [0.0, 0.0, 1.0]
    M2 = Mmag .* [sin(θ), 0.0, cos(θ)]
    return M1, M2
end

function diagonalize_layers(ks, θ)
    M1, M2 = magnetizations(θ)

    E1 = zeros(Float64, 2, length(ks))
    E2 = zeros(Float64, 2, length(ks))
    U1 = Vector{Matrix{ComplexF64}}(undef, length(ks))
    U2 = Vector{Matrix{ComplexF64}}(undef, length(ks))

    for (ik, k) in enumerate(ks)
        F1 = eigen(Hermitian(h_layer(k, M1; layer=1)))
        F2 = eigen(Hermitian(h_layer(k, M2; layer=2)))
        E1[:, ik] .= F1.values
        E2[:, ik] .= F2.values
        U1[ik] = Matrix{ComplexF64}(F1.vectors)
        U2[ik] = Matrix{ComplexF64}(F2.vectors)
    end

    return (; M1, M2, E1, E2, U1, U2)
end

function green_R(h, ω; η=ηe)
    return inv((ω + im*η) * σ_spin_0 - h)
end

green_A(h, ω; η=ηe) = green_R(h, ω; η=η)'

green_less(h, ω; η=ηe) = fermi(ω) * (green_A(h, ω; η=η) - green_R(h, ω; η=η));

# %%
#ks = -pi:0.1:pi
e1(k) = eigen(h_layer(k, [0.,0.,1.0]; layer=1)).values
e2(k) = eigen(h_layer(k, [0.5,0.0,0.0]; layer=2)).values
# #eigen(h_layer(k, [0.,0.,1.0]; layer=1))
plt.ylabel(L"E_{1/2}(k)")
plt.xlabel("k/a")
plt.plot(ks,e1.(ks))
plt.plot(ks,e2.(ks))
#(E1,E2, )=diagonalize_layers(ks, 0.0)
# Out:
# /opt/pkg/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /opt/pkg/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f7fc6a2b230>
#  PyObject <matplotlib.lines.Line2D object at 0x7f7fc6a2b260>

# %%
function polarization_R_langreth(Ωs, ωs, ks, θ)
    M1, M2 = magnetizations(θ)
    Π = zeros(ComplexF64, 4, 4, length(Ωs))

    for k in ks
        h1 = h_layer(k, M1; layer=1)
        h2 = h_layer(k, M2; layer=2)

        for (iΩ, Ω) in enumerate(Ωs)
            acc = zeros(ComplexF64, 4, 4)
            for ω in ωs
                G1R = green_R(h1, ω + Ω)
                G1L = green_less(h1, ω + Ω)
                G2A = green_A(h2, ω)
                G2L = green_less(h2, ω)

                for μ in 1:4, ν in 1:4
                    Γμ = Γ_exciton[μ]
                    Γν = Γ_exciton[ν]
                    acc[μ, ν] += tr(Γμ' * G1R * Γν * G2L + Γμ' * G1L * Γν * G2A)
                end
            end
            Π[:, :, iΩ] .+= (-im) * acc * dω / (2π * length(ks))
        end
    end

    return Π
end

function polarization_R_band_benchmark(Ωs, ks, θ)
    data = diagonalize_layers(ks, θ)
    Π = zeros(ComplexF64, 4, 4, length(Ωs))

    for (ik, _) in enumerate(ks)
        U1k = data.U1[ik]
        U2k = data.U2[ik]
        Mμ = [U1k' * Γ_exciton[μ] * U2k for μ in 1:4]

        for a in 1:2, b in 1:2
            ΔE = data.E1[a, ik] - data.E2[b, ik]
            occ = fermi(data.E2[b, ik]) - fermi(data.E1[a, ik])

            for (iΩ, Ω) in enumerate(Ωs)
                denom = Ω + im*ηΩ - ΔE
                pref = occ / denom / length(ks)
                for μ in 1:4, ν in 1:4
                    Π[μ, ν, iΩ] += pref * Mμ[μ][a, b] * conj(Mμ[ν][a, b])
                end
            end
        end
    end

    return Π, data
end

function exciton_propagator(Π; V=V)
    D = similar(Π)
    VinvI = (1/V) * Matrix{ComplexF64}(I, 4, 4)
    for iΩ in axes(Π, 3)
        D[:, :, iΩ] .= inv(VinvI - Π[:, :, iΩ])
    end
    return D
end

function spectral_trace(D)
    return [-2 * imag(tr(D[:, :, iΩ])) for iΩ in axes(D, 3)]
end;

# %%
# println("Calculando Pi^R con Langreth + integral en frecuencia...")
# Π = polarization_R_langreth(Ωs, ωs, ks, θ)
# D = exciton_propagator(Π)
# AD = spectral_trace(D)

println("Calculando benchmark de bandas...")
Π_band, layer_data = polarization_R_band_benchmark(Ωs, ks, θ)
D_band = exciton_propagator(Π_band)
AD_band = spectral_trace(D_band)

println("M1 = ", layer_data.M1)
println("M2 = ", layer_data.M2)
println("theta/pi = ", θ/π)
println("cos(theta) = ", dot(layer_data.M1, layer_data.M2)/(norm(layer_data.M1)*norm(layer_data.M2)))
# Out:
# Calculando benchmark de bandas...
# M1 = [0.0, 0.0, 1.0]
# M2 = [0.0, 0.0, 1.0]
# theta/pi = 0.0
# cos(theta) = 1.0

# %% [markdown]
# ## Figura 1: continuo electrón-hueco bare
#
# Antes de mirar el propagador excitónico, conviene ver las transiciones de una partícula que forman el continuo bare:
#
# $$\Delta E_{ab}(k)=E^1_a(k)-E^2_b(k).$$
#
# Si aparece un pico fuerte de $D^R$ cerca de un borde o separado de este continuo, lo interpretamos como modo excitónico ligado/colectivo. Esta figura no usa todavía $V$ ni la BSE; solo muestra la cinemática de pares electrón-hueco para el ángulo fijo.

# %%
fig, ax = subplots(figsize=(6.8, 4.4))
colors = ["#4d4d4d", "#737373", "#969696", "#bdbdbd"]
idx = 1
for a in 1:2, b in 1:2
    ΔEab = layer_data.E1[a, :] .- layer_data.E2[b, :]
    ax.plot(ks, ΔEab; color=colors[idx], lw=1.5, label="a=$a, b=$b")
    idx += 1
end
ax.axhline(0, color="black", lw=0.8, alpha=0.45)
ax.set_xlabel("k")
ax.set_ylabel("Delta E_ab(k)")
ax.set_title("Bare electron-hole continuum, theta/pi = $(round(θ/π; digits=3))")
ax.set_xlim(first(ks), last(ks))
ax.grid(alpha=0.18)

ax.legend(frameon=false, ncol=2)
fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 680x440 with 1 Axes>)

# %% [markdown]
# ## Figura 2: respuesta bare vs respuesta excitónica BSE
#
# Primero calculamos la respuesta electrón-hueco **bare**
#
# $$A_\Pi(\Omega)=-2\,\mathrm{Im}\,\mathrm{Tr}_\mu \Pi^R_{\mu\mu}(\Omega).$$
#
# Esta curva viene de la burbuja y representa el continuo de pares electrón-hueco antes de resumir la interacción atractiva.
#
# Luego resolvemos la BSE/RPA
#
# $$D^R(\Omega)=[V^{-1}I-\Pi^R(\Omega)]^{-1}$$
#
# y graficamos
#
# $$A_D(\Omega)=-2\,\mathrm{Im}\,\mathrm{Tr}_\mu D^R_{\mu\mu}(\Omega).$$
#
# La comparación $A_\Pi$ vs $A_D$ es la que muestra qué hace la interacción excitónica: si $D^R$ desarrolla un pico fuerte, desplazado o separado del continuo bare, eso indica un modo excitónico o una resonancia excitónica. También marcamos el mínimo de $|\det[V^{-1}I-\Pi^R]|$, que localiza la condición de polo BSE.

# %%
# AΠ = [-2 * imag(tr(Π[:, :, iΩ])) for iΩ in axes(Π, 3)]
# detvals = [abs(det((1/V) * Matrix{ComplexF64}(I, 4, 4) - Π[:, :, iΩ])) for iΩ in axes(Π, 3)]
# i_peak = argmax(AD)
# i_det = argmin(detvals)

# Π and D do not have the same units/scale. Plot a rescaled bare response
# only as a shape/continuum reference on the same axis.
# scale_AΠ = 1.0#maximum(abs.(AΠ)) > 0 ? maximum(abs.(AD)) / maximum(abs.(AΠ)) : 1.0
# AΠ_scaled = scale_AΠ .* AΠ

fig, ax = subplots(figsize=(7.2, 4.6))
# ax.plot(Ωs, AΠ_scaled; color="#8c8c8c", lw=1.7, alpha=0.85, label="bare bubble -2 Im Tr Pi (scaled)")
# ax.plot(Ωs, AD; color="black", lw=2.3, label="BSE D from Langreth Pi")
ax.plot(Ωs, AD_band; color="#2c7fb8", lw=1.2, ls="--", alpha=0.6, label="D band benchmark")
#ax.axvline(Ωs[i_peak], color="black", lw=1.0, ls=":", label="D peak")
#ax.axvline(Ωs[i_det], color="#d95f0e", lw=1.0, ls="--", label="min det")
ax.set_xlabel("Omega")
ax.set_ylabel("-Im Dr")
ax.set_title("Bare electron-hole response vs excitonic BSE response")
ax.grid(alpha=0.18)
ax.legend(frameon=false)
ax.set_xlim(0, 15)

ax.axvline(3.3)

fig.tight_layout()

# @printf("Langreth D peak: Omega = %+8.5f, weight = %+10.6f\n", Ωs[i_peak], AD[i_peak])
# @printf("min |det(V^{-1}I-Pi)|: Omega = %+8.5f, value = %.6e\n", Ωs[i_det], detvals[i_det])
# @printf("bare bubble scaling factor used in plot: %.6e\n", scale_AΠ)
# Out:
# Figure(PyObject <Figure size 720x460 with 1 Axes>)

# %% [markdown]
# ## Figura 3: composición en canales carga/spin
#
# Finalmente separamos los canales diagonales del propagador excitónico:
#
# $$A_\mu(\Omega)=-2\,\mathrm{Im}\,D^R_{\mu\mu}(\Omega),\qquad \mu=0,x,y,z.$$
#
# Esto muestra si el modo excitónico es principalmente de carga, spin longitudinal/transversal, o si la no colinealidad entre $\mathbf M_1$ y $\mathbf M_2$ mezcla varios canales.

# %%
fig, ax = subplots(figsize=(6.8, 4.4))
for μ in 1:4
    Aμμ = [-2 * imag(D_band[μ, μ, iΩ]) for iΩ in axes(D_band, 3)]
    ax.plot(Ωs, Aμμ; lw=1.8, label=channel_labels[μ])
end
ax.set_xlabel("Omega")
ax.set_ylabel("-2 Im D^R_mu,mu")
ax.set_title("Charge/spin channel content")
ax.grid(alpha=0.18)
ax.legend(frameon=false, title=L"$\mu$")
ax.set_xlim(0, 15)





fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 680x440 with 1 Axes>)

# %%
fig, ax = subplots(figsize=(6.8, 4.4))
Aμμ = [-2 * imag(D_band[4, 4, iΩ]) for iΩ in axes(D_band, 3)]
ax.plot(Ωs, Aμμ; lw=1.8, label="12")

fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 680x440 with 1 Axes>)

# %% [markdown]
# ## Diagnóstico adicional: mezcla entre canales
#
# Como chequeo numérico rápido, imprimimos
#
# $$\max_\Omega |\Pi^R_{\mu\nu}(\Omega)|.$$
#
# Para configuraciones colineales debería haber una estructura más bloque-diagonal. Para ángulos no colineales, la mezcla entre canales es parte de la física esperada.

# %%
mixing = zeros(Float64, 4, 4)
for μ in 1:4, ν in 1:4
    mixing[μ, ν] = maximum(abs.(Π_band[μ, ν, :]))
end

println("max_Omega |Pi_{μν}(Omega;theta)|")
print("      ")
for label in channel_labels
    @printf("%12s", label)
end
println()
for μ in 1:4
    @printf("%4s  ", channel_labels[μ])
    for ν in 1:4
        @printf("%12.5e", mixing[μ, ν])
    end
    println()
end
# Out:
# max_Omega |Pi_{μν}(Omega;theta)|
#                  0           x           y           z
#    0   5.78866e-01 0.00000e+00 0.00000e+00 3.60238e-01
#    x   0.00000e+00 8.81763e-01 3.25116e-17 0.00000e+00
#    y   0.00000e+00 3.25116e-17 8.81763e-01 0.00000e+00
#    z   3.60238e-01 0.00000e+00 0.00000e+00 5.78866e-01

# %% [markdown]
# ## Barrido angular rápido con la fórmula de bandas
#
# Para barrer muchos ángulos usamos la forma de bandas de la burbuja. En el caso de equilibrio, electrones no interactuantes y magnetizaciones congeladas, esta es la evaluación analítica de la burbuja de Langreth:
#
# $$\Pi^R_{\mu\nu}(\Omega;\theta)=\frac{1}{L}\sum_{k,a,b}\frac{f(E^2_{bk})-f(E^1_{ak})}{\Omega+i\eta-(E^1_{ak}-E^2_{bk})}M^\mu_{ab}(k)M^{\nu *}_{ab}(k).$$
#
# Esto permite calcular rápidamente
#
# $$A_D(\Omega,\theta)=-2\,\mathrm{Im}\,\mathrm{Tr}\,D^R(\Omega;\theta)$$
#
# para muchos valores de $\theta$. Esta es la figura que prueba directamente la hipótesis de que el problema se caracteriza por el ángulo relativo entre las magnetizaciones.

# %%
function continuum_edges(data)
    emin = Inf
    emax = -Inf
    for a in 1:2, b in 1:2
        ΔEab = data.E1[a, :] .- data.E2[b, :]
        emin = min(emin, minimum(ΔEab))
        emax = max(emax, maximum(ΔEab))
    end
    return emin, emax
end

function solve_angle_band(θval; Ωs=Ωs, ks=ks, V=V)
    Πθ, dataθ = polarization_R_band_benchmark(Ωs, ks, θval)
    Dθ = exciton_propagator(Πθ; V=V)
    ADθ = spectral_trace(Dθ)
    detθ = [abs(det((1/V) * Matrix{ComplexF64}(I, 4, 4) - Πθ[:, :, iΩ])) for iΩ in axes(Πθ, 3)]
    ipeak = argmax(ADθ)
    idet = argmin(detθ)
    cmin, cmax = continuum_edges(dataθ)
    return (; θ=θval, Π=Πθ, D=Dθ, AD=ADθ, detvals=detθ,
            Ωpeak=Ωs[ipeak], Apeak=ADθ[ipeak], Ωdet=Ωs[idet], detmin=detθ[idet],
            continuum_min=cmin, continuum_max=cmax, data=dataθ)
end;

# %%
Nθ = 25
θs = collect(range(0, π, length=Nθ))

println("Running band-method angle sweep with Nθ=$Nθ, NΩ=$(length(Ωs)), L=$(length(ks))")
sweep = [solve_angle_band(θval) for θval in θs]

AD_map = reduce(hcat, [s.AD for s in sweep])'          # size Nθ x NΩ
Ωpeaks = [s.Ωpeak for s in sweep]
Apeaks = [s.Apeak for s in sweep]
Ωdets = [s.Ωdet for s in sweep]
cont_min = [s.continuum_min for s in sweep]
cont_max = [s.continuum_max for s in sweep]

@printf("θ/pi range: %.3f to %.3f\n", first(θs)/π, last(θs)/π)
@printf("peak Ω range: %.5f to %.5f\n", minimum(Ωpeaks), maximum(Ωpeaks))
@printf("continuum lower edge range: %.5f to %.5f\n", minimum(cont_min), maximum(cont_min))
# Out:
# Running band-method angle sweep with Nθ=25, NΩ=401, L=100
# θ/pi range: 0.000 to 1.000
# peak Ω range: 3.33750 to 3.33750
# continuum lower edge range: 2.80000 to 2.80000

# %% [markdown]
# ## Figura 4: mapa espectral $A_D(\Omega,\theta)$
#
# La intensidad muestra el espectro excitónico BSE calculado con la burbuja de bandas. Las curvas superpuestas marcan:
#
# - pico principal de $A_D$ para cada ángulo,
# - mínimo de $|\det[V^{-1}I-\Pi^R]|$,
# - bordes inferior y superior del continuo bare.
#
# Si el modo excitónico está ligado, su rama debe aparecer por debajo del borde inferior del continuo. Si está dentro, es una resonancia excitónica.

# %%
fig, ax = subplots(figsize=(8.0, 5.2))
θ_over_pi = θs ./ π
im = ax.imshow(AD_map; origin="lower", aspect="auto",
               extent=(first(Ωs), last(Ωs), first(θ_over_pi), last(θ_over_pi)),
               cmap="magma")
ax.plot(Ωpeaks, θ_over_pi; color="cyan", lw=1.6, label="AD peak")
ax.plot(Ωdets, θ_over_pi; color="white", lw=1.2, ls="--", label="min det")
ax.plot(cont_min, θ_over_pi; color="#7dd3fc", lw=1.2, ls=":", label="continuum min")
ax.plot(cont_max, θ_over_pi; color="#7dd3fc", lw=1.2, ls="-.", label="continuum max")
ax.set_xlabel("Omega")
ax.set_ylabel("theta/pi")
ax.set_title("Angle-resolved excitonic BSE spectrum")
ax.set_xlim(0, 10)
ax.legend(frameon=false, loc="upper right")
fig.colorbar(im, ax=ax, label="-2 Im Tr D^R")
fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 800x520 with 2 Axes>)

# %% [markdown]
# ## Figura 5: mapas espectrales por canal
#
# La traza total puede ser casi independiente de $\theta$ porque el problema es rotacionalmente invariante si $V$ es proporcional a la identidad en el espacio de canales. Para ver si el ángulo redistribuye peso entre canales, graficamos por separado
#
# $$A_\mu(\Omega,\theta)=-2\,\mathrm{Im}\,D^R_{\mu\mu}(\Omega;\theta),\qquad \mu=0,x,y,z.$$
#
# Estos mapas no vuelven a calcular la burbuja: usan los propagadores guardados en `sweep`.

# %%
component_maps = [reduce(hcat, [[-2 * imag(s.D[μ, μ, iΩ]) for iΩ in axes(s.D, 3)] for s in sweep])' for μ in 1:4]

fig, axs = subplots(2, 2, figsize=(9.0, 6.6), sharex=true, sharey=true)
axs_flat = vec(axs)
θ_over_pi = θs ./ π
vmax_comp = maximum(abs.(vcat([vec(Aμ) for Aμ in component_maps]...)))
vmax_comp = vmax_comp > 0 ? vmax_comp : 1.0

for μ in 1:4
    ax = axs_flat[μ]
    im = ax.imshow(component_maps[μ]; origin="lower", aspect="auto",
                   extent=(first(Ωs), last(Ωs), first(θ_over_pi), last(θ_over_pi)),
                   cmap="magma", vmin=0, vmax=vmax_comp)
    ax.plot(cont_min, θ_over_pi; color="#7dd3fc", lw=1.0, ls=":")
    ax.plot(cont_max, θ_over_pi; color="#7dd3fc", lw=1.0, ls="-.")
    ax.set_xlim(0, 10)
    ax.set_title("channel " * channel_labels[μ])
    ax.grid(alpha=0.10)
end

axs[2, 1].set_xlabel("Omega")
axs[2, 2].set_xlabel("Omega")
axs[1, 1].set_ylabel("theta/pi")
axs[2, 1].set_ylabel("theta/pi")
fig.colorbar(im, ax=axs_flat, shrink=0.86, label="-2 Im D_mumu")
fig.suptitle("BSE spectral maps by exciton channel")
fig.tight_layout(rect=(0, 0, 0.92, 0.95))
# Out:
# sys:1: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# Figure(PyObject <Figure size 900x660 with 5 Axes>)

# %% [markdown]
# ## Figura 5: energía del modo vs ángulo
#
# Esta figura resume la anterior reduciendo cada espectro a la energía del pico principal y al mínimo del determinante. Es útil para ver si la rama excitónica depende principalmente de $\cos\theta$.

# %%
xcos = cos.(θs)
order = sortperm(xcos)

fig, ax = subplots(figsize=(6.8, 4.4))
ax.plot(xcos[order], Ωpeaks[order]; marker="o", lw=1.8, label="AD peak")
ax.plot(xcos[order], Ωdets[order]; marker="s", lw=1.4, ls="--", label="min det")
ax.fill_between(xcos[order], cont_min[order], cont_max[order]; color="#bdbdbd", alpha=0.25, label="bare continuum")
ax.set_xlabel("cos(theta)")
ax.set_ylabel("Omega")
ax.set_title("Excitonic mode energy vs relative spin angle")
ax.grid(alpha=0.18)
ax.legend(frameon=false)


ax.set_ylim(3.0,3.5)
fig.tight_layout()
# Out:
# Figure(PyObject <Figure size 680x440 with 1 Axes>)

# %% [markdown]
# ## Qué mirar después
#
# Para convertir esto en una caracterización por ángulo, el siguiente paso es envolver las celdas anteriores en una función `solve_angle(θ)` y barrer `θ ∈ [0,π]`. La figura central después será un mapa de color
#
# $$A_D(\Omega,\theta)=-2\,\mathrm{Im}\,\mathrm{Tr}\,D^R(\Omega;\theta),$$
#
# con eje horizontal `Ω` y eje vertical `θ` o `cos(θ)`.
